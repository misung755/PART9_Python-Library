# %% [markdown]
# # Review

# %% [markdown]
# ### 0.라이브러리 불러오기 & 데이터 업로드

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/diamonds.csv'
                 , sep=',', skipinitialspace=True)  

data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# #### 변수 설명
# * carat : weight of the diamond (0.2 ~ 5.01)
# * cut : quality of the cut (Fair, Good, Very Good, Premium, Ideal)
# * color : diamond colour, from J (worst) to D (best)
# * clarity : a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# * depth : total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43 ~ 79)
# * table : width of top of diamond relative to widest point (43 ~ 95)
# * price : price in US dollars (326 ~ 18,823)
# * x : length in mm (0 ~ 10.74)
# * y : width in mm (0 ~ 58.9)
# * z : depth in mm (0 ~ 31.8)

# %% [markdown]
# ### 다음의 문제를 풀어봅시다.

# %% [markdown]
# #### 1. 데이터프레임 변수(칼럼)별 데이터 타입을 조회하시오.

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %% [markdown]
# #### 2. 데이터 프레임에서 행인덱스 1000에서 2000까지 조회하시오.

# %%
data.iloc[1000:2001]
# Out:
#       carat        cut color clarity  depth  table  price     x     y     z
# 1000   0.75      Ideal     D     SI1   62.3   55.0   2898  5.83  5.80  3.62
# 1001   0.77      Ideal     D     SI1   62.6   57.0   2898  5.92  5.81  3.67
# 1002   0.98       Good     H     SI2   57.9   56.0   2898  6.51  6.47  3.76
# 1003   0.79      Ideal     G     SI1   61.1   57.0   2898  5.98  5.93  3.64
# 1004   0.79      Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# ...     ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 1996   0.53      Ideal     D    VVS1   61.6   55.0   3097  5.21  5.27  3.23
# 1997   1.29       Good     I      I1   64.2   54.0   3098  6.93  6.83  4.42
# 1998   0.90  Very Good     I     SI2   60.4   58.0   3099  6.25  6.31  3.79
# 1999   0.72      Ideal     D     VS2   61.8   57.0   3099  5.76  5.73  3.55
# 2000   0.94    Premium     G     SI2   63.0   59.0   3099  6.16  6.10  3.86
#
# [1001 rows x 10 columns]

# %%
data.iloc[1000:2001,]
# Out:
#       carat        cut color clarity  depth  table  price     x     y     z
# 1000   0.75      Ideal     D     SI1   62.3   55.0   2898  5.83  5.80  3.62
# 1001   0.77      Ideal     D     SI1   62.6   57.0   2898  5.92  5.81  3.67
# 1002   0.98       Good     H     SI2   57.9   56.0   2898  6.51  6.47  3.76
# 1003   0.79      Ideal     G     SI1   61.1   57.0   2898  5.98  5.93  3.64
# 1004   0.79      Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# ...     ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 1996   0.53      Ideal     D    VVS1   61.6   55.0   3097  5.21  5.27  3.23
# 1997   1.29       Good     I      I1   64.2   54.0   3098  6.93  6.83  4.42
# 1998   0.90  Very Good     I     SI2   60.4   58.0   3099  6.25  6.31  3.79
# 1999   0.72      Ideal     D     VS2   61.8   57.0   3099  5.76  5.73  3.55
# 2000   0.94    Premium     G     SI2   63.0   59.0   3099  6.16  6.10  3.86
#
# [1001 rows x 10 columns]

# %%
data.loc[1000:2001]
# data.loc[1000:2001,]
# Out:
#       carat        cut color clarity  depth  table  price     x     y     z
# 1000   0.75      Ideal     D     SI1   62.3   55.0   2898  5.83  5.80  3.62
# 1001   0.77      Ideal     D     SI1   62.6   57.0   2898  5.92  5.81  3.67
# 1002   0.98       Good     H     SI2   57.9   56.0   2898  6.51  6.47  3.76
# 1003   0.79      Ideal     G     SI1   61.1   57.0   2898  5.98  5.93  3.64
# 1004   0.79      Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# ...     ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 1997   1.29       Good     I      I1   64.2   54.0   3098  6.93  6.83  4.42
# 1998   0.90  Very Good     I     SI2   60.4   58.0   3099  6.25  6.31  3.79
# 1999   0.72      Ideal     D     VS2   61.8   57.0   3099  5.76  5.73  3.55
# 2000   0.94    Premium     G     SI2   63.0   59.0   3099  6.16  6.10  3.86
# 2001   0.93      Ideal     I     SI2   62.3   57.0   3101  6.20  6.22  3.87
#
# [1002 rows x 10 columns]

# %% [markdown]
# #### 3. 데이터프레임에서 carat 변수를 조회하시오.
# 조회시 결과가 다음 두가지로 나오게 하시오

# %%
# Series
data.carat
#data['carat']
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
# Dataframe
data[['carat']]
# Out:
#        carat
# 0       0.23
# 1       0.21
# 2       0.23
# 3       0.29
# 4       0.31
# ...      ...
# 53935   0.72
# 53936   0.72
# 53937   0.70
# 53938   0.86
# 53939   0.75
#
# [53940 rows x 1 columns]

# %% [markdown]
# #### 4. color가 E 이고, price가 5000 달러보다 큰 다이아몬드를 조회하시오

# %%
(data.color == 'E') & (data['price'] > 5000)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Length: 53940, dtype: bool

# %%
data.loc[(data.color == 'E') & (data['price'] > 5000)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 11416   1.16      Ideal     E     SI2   62.7   56.0   5001  6.69  6.73  4.21
# 11417   1.16      Ideal     E     SI2   59.9   57.0   5001  6.80  6.82  4.08
# 11419   0.90  Very Good     E     VS1   62.3   56.0   5001  6.10  6.19  3.83
# 11426   1.01  Very Good     E     SI1   63.4   59.0   5002  6.38  6.34  4.03
# 11427   1.01  Very Good     E     SI1   63.1   60.0   5002  6.37  6.34  4.01
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27637   1.72  Very Good     E     VS2   63.4   56.0  18557  7.65  7.55  4.82
# 27677   1.28      Ideal     E      IF   60.7   57.0  18700  7.09  6.99  4.27
# 27683   2.00  Very Good     E     SI1   60.5   59.0  18709  8.09  8.14  4.94
# 27688   1.51      Ideal     E     VS1   61.5   57.0  18729  7.34  7.40  4.53
# 27720   2.02  Very Good     E     SI1   59.8   59.0  18731  8.11  8.20  4.88
#
# [1726 rows x 10 columns]

# %% [markdown]
# #### 5. 가장 가격이 비싼 다이아몬드를 조회하시오.

# %%
data.price.max()
# Out:
# 18823

# %%
data.price == data.price.max()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Name: price, Length: 53940, dtype: bool

# %%
data.loc[data.price == data.price.max()]
# Out:
#        carat      cut color clarity  depth  table  price    x     y     z
# 27749   2.29  Premium     I     VS2   60.8   60.0  18823  8.5  8.47  5.16

# %% [markdown]
# #### 6. 데이터프레임에 volume 변수를 추가하시오. volume은 x * y * z 로 계산합니다.

# %%
data['volume'] = data['x'] * data['y'] * data['x']
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#       volume
# 0  62.097950
# 1  58.107264
# 2  66.758175
# 3  74.617200
# 4  81.934860

# %% [markdown]
# #### 7. cut 별 평균 가격을 조회하시오.

# %%
data.groupby(by = 'cut')['price'].mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
data.groupby(by = 'cut')[['price']].mean()
# Out:
#                  price
# cut
# Fair       4358.757764
# Good       3928.864452
# Ideal      3457.541970
# Premium    4584.257704
# Very Good  3981.759891

# %%
data.groupby(by = 'cut',as_index = False)[['price']].mean().rename(columns = {'price' : 'avgPrice'})
# Out:
#          cut     avgPrice
# 0       Fair  4358.757764
# 1       Good  3928.864452
# 2      Ideal  3457.541970
# 3    Premium  4584.257704
# 4  Very Good  3981.759891

# %% [markdown]
# #### 8. cut별 평균 carat을 조회하시오.

# %%
data.groupby(by = 'cut',as_index = False)[['carat']].mean().rename(columns = {'carat' : 'avgCarat'})
# Out:
#          cut  avgCarat
# 0       Fair  1.046137
# 1       Good  0.849185
# 2      Ideal  0.702837
# 3    Premium  0.891955
# 4  Very Good  0.806381

# %% [markdown]
# #### 9. 7,8번의 결과를 각각 저장하고, merge로 합치시오.

# %%
avgPrice_cut = data.groupby(by = 'cut',as_index = False)[['price']].mean().rename(columns = {'price' : 'avgPrice'})
avgCarat_cut = data.groupby(by = 'cut',as_index = False)[['carat']].mean().rename(columns = {'carat' : 'avgCarat'})

# %%
pd.merge(avgPrice_cut, avgCarat_cut)
# Out:
#          cut     avgPrice  avgCarat
# 0       Fair  4358.757764  1.046137
# 1       Good  3928.864452  0.849185
# 2      Ideal  3457.541970  0.702837
# 3    Premium  4584.257704  0.891955
# 4  Very Good  3981.759891  0.806381

# %%
pd.merge(avgPrice_cut, avgCarat_cut, how = 'inner', on = 'cut')
# Out:
#          cut     avgPrice  avgCarat
# 0       Fair  4358.757764  1.046137
# 1       Good  3928.864452  0.849185
# 2      Ideal  3457.541970  0.702837
# 3    Premium  4584.257704  0.891955
# 4  Very Good  3981.759891  0.806381

# %% [markdown]
# #### 10. 행을 칼라로, 열을 cut으로 평균 가격을 집계한 정보를 pivot table로 조회하시오.

# %%
data2 = data.groupby(by = ['color','cut'], as_index = False)['price'].mean()
data2.head()
# Out:
#   color        cut        price
# 0     D       Fair  4291.061350
# 1     D       Good  3405.382175
# 2     D      Ideal  2629.094566
# 3     D    Premium  3631.292576
# 4     D  Very Good  3470.467284

# %%
a = data2.pivot('color', 'cut', 'price')

# %%
a.reset_index()
# Out:
# cut color         Fair         Good        Ideal      Premium    Very Good
# 0       D  4291.061350  3405.382175  2629.094566  3631.292576  3470.467284
# 1       E  3682.312500  3423.644159  2597.550090  3538.914420  3214.652083
# 2       F  3827.003205  3495.750275  3374.939362  4324.890176  3778.820240
# 3       G  4239.254777  4123.482204  3720.706388  4500.742134  3872.753806
# 4       H  5135.683168  4276.254986  3889.334831  5216.706780  4535.390351
# 5       I  4685.445714  5078.532567  4451.970377  5946.180672  5255.879568
# 6       J  4975.655462  4574.172638  4918.186384  6294.591584  5103.513274

# %% [markdown]
# #### 11. carat과 price와의 관계를 시각화하시오.(산점도를 그리시오)

# %%
data.plot('carat', 'price', kind = 'scatter')
plt.show()

# %% [markdown]
# #### 12. 10번의 그림에서 얻게되는 정보를 3가지 찾아보시오.

# %% [markdown]
#     1)
#
#     2)
#
#     3)
